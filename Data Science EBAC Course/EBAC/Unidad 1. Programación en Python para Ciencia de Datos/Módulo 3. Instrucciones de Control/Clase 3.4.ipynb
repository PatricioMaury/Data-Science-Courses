# %% [markdown]
# # Estructuras TRY y EXCEPT

# %%
cadena1 = '123'
entero = int(cadena1)
print(entero)
# Out:
# 123

# %%
cadena = input('Dame un entero positivo: ')
try:
    entero = int(cadena)
except:
    entero = -1

if entero > 0:
    print('Valor correcto')
else:
    print('Valor incorrecto')
# Out:
# Dame un entero positivo:  21
# Valor correcto

# %%
cadena = input('Dame un entero positivo: ')
try:
    entero = int(cadena)
except:
    entero = -1

if entero > 0:
    print('Valor correcto')
else:
    print('Valor incorrecto')
# Out:
# Dame un entero positivo:  Pablo
# Valor incorrecto

# %% [markdown]
# # Usos avanzados de IF

# %%
lluvia = True
print('Vamos a', 'la playa' if not lluvia else 'la biblioteca')
# Out:
# Vamos a la biblioteca

# %%
x = y = 40
z = x + 1 if x > y else y + 2
z
# Out:
# 42

# %%
x = 3
s = ('abc' if (x == 1) else
     'def' if (x == 2) else
     'ghi' if (x == 4) else
     'mno')
s
# Out:
# 'mno'

# %%
'Si' if ('jkl' in ['abc', 'def', 'ghi']) else 'No'
# Out:
# 'No'

# %%
'Si' if ('jkl' in ['abc', 'def', 'ghi', 'jkl']) else 'No'
# Out:
# 'Si'
