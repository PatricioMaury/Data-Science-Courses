# %% [markdown]
# # Tablas de Verdad

# %%
a = -5
b = 4

# %%
# El valor de a es menor a 0?
a < 0
# Out:
# True

# %%
# El valor de a es mayor o igual a 0?
a >= 0
# Out:
# False

# %%
# El valor de a es igual a -5?
a == -5
# Out:
# True

# %%
# El valor de a distinto a -5?
a != -5
# Out:
# False

# %% [markdown]
# ### Manejo de Conjunciones (AND)

# %%
a = -5
b = 4

# %%
a < 0 and b > 0
# Out:
# True

# %%
a > 0 and b > 0
# Out:
# False

# %%
a < 0 and b < 0
# Out:
# False

# %%
a > 0 and b < 0
# Out:
# False

# %% [markdown]
# ### Manejo de Disyunciones (OR)

# %%
a = -5
b = 4

# %%
a < 0 or b > 0
# Out:
# True

# %%
a > 0 or b > 0
# Out:
# True

# %%
a < 0 or b < 0
# Out:
# True

# %%
a > 0 or b < 0
# Out:
# False

# %% [markdown]
# ### Operador de Negación (NOT)

# %%
a = -5
b = 4

# %%
not a > 0
# Out:
# True

# %% [markdown]
# ### Operador de Disyunción Opuesta (NOR (NOT OR))

# %%
a = -5
b = 4

# %%
not (a < 0 or b > 0)
# Out:
# False

# %%
not (a > 0 or b < 0)
# Out:
# True

# %% [markdown]
# ### Casos Especiales

# %%
a = -5
b = 4

# %%
a += 5 #Equivalente a: a = a + 5
a < 0
# Out:
# False

# %%
a
# Out:
# 0

# %%
b %= 3 #Equivalente a: b = b % 3
b
# Out:
# 1

# %%
c = 5
c //= 2 #Equivalente a tomar la parte entera de la división de 5 entre 2
c
# Out:
# 2

# %%
a = 4
b = 5
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
texto1 = 'Hola'
texto2 = 'Hola'
texto3 = 'hola'

# %%
texto1 is texto2
# Out:
# True

# %%
texto1 is texto3
# Out:
# False

# %%
a = [1, 2, 3, 4, 5]

# %%
3 in a #Checar si el valor de 3 está en la lista a
# Out:
# True

# %%
7 in a
# Out:
# False

# %%
texto = 'Hola mundo'

# %%
'Hola' in texto
# Out:
# True

# %%
'hola' in texto
# Out:
# False
